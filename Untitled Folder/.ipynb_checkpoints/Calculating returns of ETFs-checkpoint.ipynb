# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sn
from tabulate import tabulate
import datetime
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from scipy.optimize import minimize
import matplotlib.patches as mpatches
import plotly.graph_objects as go
from scipy import stats

# %%
### Loading the data 
df=pd.read_csv("C:\\Users\\Pratiksha Sharma\\Desktop\\NewKibotData\\MasterFile9July.csv")
df=df.rename(columns = {'Unnamed: 0':'stock_name'})
df=df.drop('Unnamed: 1',axis=1)
df.Date=pd.to_datetime(df.Date)
# Out:
#               XLB          XLE          XLF          XLI          XLK  \
# count  5412.00000  5412.000000  5412.000000  5412.000000  5412.000000
# mean     30.29733    42.460879    13.631922    34.771489    31.495243
# std      14.07843    18.234632     5.978272    18.824871    19.914167
# min      10.85800    12.964000     3.097500    12.065000     8.981000
# 25%      17.59300    21.307500     9.633000    20.160000    17.372250
# 50%      28.42500    44.710000    12.124000    26.990000    22.915000
# 75%      42.00000    57.700000    15.135250    48.262500    39.382500
# max      60.80000    80.560000    30.710000    84.180000   108.110000
#
#                XLP          XLU          XLV          XLY
# count  5412.000000  5412.000000  5412.000000  5412.000000
# mean     27.867904    27.237603    40.257302    45.966089
# std      14.779145    14.078599    24.255819    30.927839
# min      11.544000     8.009000    16.213000    13.543000
# 25%      15.873500    15.703500    22.127500    23.190000
# 50%      20.130000    23.270000    26.615000    29.905000
# 75%      41.910000    36.452500    62.442500    67.395000
# max      63.930000    69.680000   103.790000   132.970000

# %% [markdown]
# ### Creating a dataframe with the daily closing prices for all the ETFs

# %%
dfclose = df[['Date', 'stock_name', 'Close']]
closing = dfclose.set_index('Date')
closing = closing.pivot(columns='stock_name')
closing.columns = [col[1] for col in closing.columns]
closing
closing.describe()
# Out:
#               XLB          XLE          XLF          XLI          XLK  \
# count  5412.00000  5412.000000  5412.000000  5412.000000  5412.000000
# mean     30.29733    42.460879    13.631922    34.771489    31.495243
# std      14.07843    18.234632     5.978272    18.824871    19.914167
# min      10.85800    12.964000     3.097500    12.065000     8.981000
# 25%      17.59300    21.307500     9.633000    20.160000    17.372250
# 50%      28.42500    44.710000    12.124000    26.990000    22.915000
# 75%      42.00000    57.700000    15.135250    48.262500    39.382500
# max      60.80000    80.560000    30.710000    84.180000   108.110000
#
#                XLP          XLU          XLV          XLY
# count  5412.000000  5412.000000  5412.000000  5412.000000
# mean     27.867904    27.237603    40.257302    45.966089
# std      14.779145    14.078599    24.255819    30.927839
# min      11.544000     8.009000    16.213000    13.543000
# 25%      15.873500    15.703500    22.127500    23.190000
# 50%      20.130000    23.270000    26.615000    29.905000
# 75%      41.910000    36.452500    62.442500    67.395000
# max      63.930000    69.680000   103.790000   132.970000

# %% [markdown]
# ### Calculating the daily Closing Log returns

# %%
c2cl=closing.pct_change().apply(lambda x: np.log(1+x))
c2cl=c2cl.dropna()

# %% [markdown]
# ### Calculating the daily closing returns for all the ETFs

# %%
c2c=closing.pct_change()
c2c=c2c.dropna()
c2c.describe()
# Out:
#                XLB          XLE          XLF          XLI          XLK  \
# count  5411.000000  5411.000000  5411.000000  5411.000000  5411.000000
# mean      0.000398     0.000326     0.000349     0.000461     0.000407
# std       0.015601     0.018107     0.019488     0.020700     0.016514
# min      -0.115030    -0.201316    -0.164703    -0.487058    -0.138241
# 25%      -0.007049    -0.008211    -0.007110    -0.005725    -0.006382
# 50%       0.000657     0.000511     0.000479     0.000704     0.000931
# 75%       0.008193     0.009561     0.007862     0.007022     0.007579
# max       0.121800     0.202932     0.307198     0.962298     0.171466
#
#                XLP          XLU          XLV          XLY
# count  5411.000000  5411.000000  5411.000000  5411.000000
# mean      0.000289     0.000338     0.000385     0.000599
# std       0.009987     0.012531     0.011848     0.024622
# min      -0.093645    -0.113680    -0.099378    -0.582112
# 25%      -0.004327    -0.005481    -0.005160    -0.005776
# 50%       0.000455     0.000946     0.000692     0.000783
# 75%       0.005141     0.006610     0.006313     0.007249
# max       0.093349     0.126270     0.131194     1.359243
